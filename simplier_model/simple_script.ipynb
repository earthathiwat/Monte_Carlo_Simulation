# %%
# !touch output.csv
# !python3 lowest.py

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
df = pd.DataFrame()

# %%
for i in range(10):
    # !python3 lowest.py
    output = pd.read_csv("output.csv")
    df.

# %%
df = pd.read_csv("output.csv", header=None)
df
# Out:
#         0     1      2     3
# 0     one   two  three  four
# 1    2538  2439   2560  2463
# 2    2471  2445   2601  2483
# 3    2436  2495   2544  2525
# 4    2557  2497   2478  2468
# ..    ...   ...    ...   ...
# 96   2475  2517   2500  2508
# 97   2515  2474   2516  2495
# 98   2520  2518   2498  2464
# 99   2454  2572   2491  2483
# 100  2480  2499   2501  2520
#
# [101 rows x 4 columns]

# %%
percentage = df/10000
percentage.head(5)
# Out:
#       one     two   three    four
# 0  0.2538  0.2439  0.2560  0.2463
# 1  0.2471  0.2445  0.2601  0.2483
# 2  0.2436  0.2495  0.2544  0.2525
# 3  0.2557  0.2497  0.2478  0.2468
# 4  0.2652  0.2463  0.2471  0.2414

# %%
plt.figure()
percentage.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure()
percentage[['one']].plot()
# Out:
# <AxesSubplot:>

# %%
test = pd.read_excel('Book1.xlsx')
test
# Out:
#      one   two  three  four  five   six  seven  eight  nine   ten
# 0   2530  2571   2499  2466  2590  2670   2602   2497  2670  2558
# 1   2511  2548   2559  2612  2690  2512   2510   2469  2537  2401
# 2   2472  2488   2499  2680  2551  2533   2458   2477  2538  2534
# 3   2418  2487   2534  2499  2519  2507   2492   2597  2544  2492
# 4   2484  2462   2419  2508  2526  2538   2515   2554  2533  2519
# ..   ...   ...    ...   ...   ...   ...    ...    ...   ...   ...
# 95  2472  2460   2533  2532  2544  2479   2470   2521  2497  2476
# 96  2503  2492   2481  2492  2518  2510   2461   2563  2543  2559
# 97  2427  2440   2494  2484  2498  2505   2510   2547  2511  2443
# 98  2501  2486   2552  2488  2485  2510   2509   2429  2505  2542
# 99  2518  2431   2438  2485  2524  2508   2409   2564  2414  2481
#
# [100 rows x 10 columns]

# %%
percentage = test/10000

# %%
plt.figure()
percentage.plot(legend=None, 
                linewidth=0.7,
                figsize=(12, 5))
plt.xlabel("Number of game played")
plt.ylabel("Probability of Player one winning")
plt.title("Covergence Graph")
plt.savefig('convergence.png')
